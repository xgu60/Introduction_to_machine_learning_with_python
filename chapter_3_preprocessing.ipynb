# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
#load data
data = make_blobs()

# %%
X = pd.DataFrame(data[0])
y = pd.Series(data[1])

# %%
X.head()
# Out:
#           0         1
# 0  3.370544 -2.892966
# 1  1.485198 -0.317550
# 2  4.902015 -3.399692
# 3 -2.292391 -0.119802
# 4 -0.180422 -4.367235

# %%
X.plot.scatter(x=0, y=1);

# %%
s1 = StandardScaler()
X1 = pd.DataFrame(s1.fit_transform(X))
s2 = RobustScaler()
X2 = pd.DataFrame(s2.fit_transform(X))
s3 = MinMaxScaler()
X3 = pd.DataFrame(s3.fit_transform(X))
s4 = Normalizer()
X4 = pd.DataFrame(s4.fit_transform(X))

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
X1.plot.scatter(x=0, y=1,  ax=axes[0][0])
X2.plot.scatter(x=0, y=1,  ax=axes[0][1])
X3.plot.scatter(x=0, y=1,  ax=axes[1][0])
X4.plot.scatter(x=0, y=1,  ax=axes[1][1]);
